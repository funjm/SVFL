# %%
import pandas as pd
import numpy as np

# %%
# file_path = './splite/train_data.npy'
file_path = './mfeat-fou'
df = pd.read_csv(file_path, header=None, sep='\s+')

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.065882  0.197312  0.103826  0.270362  0.616078  0.035856  0.424572
# 1     0.049142  0.175971  0.105515  0.227095  0.599280  0.041217  0.431078
# 2     0.034172  0.227649  0.108766  0.127697  0.612494  0.056554  0.470639
# 3     0.062336  0.217979  0.080243  0.289592  0.546316  0.045779  0.425545
# 4     0.061970  0.198358  0.111239  0.253460  0.608455  0.023631  0.415246
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.171874  0.221525  0.426470  0.077220  0.264413  0.220274  0.452574
# 1996  0.152025  0.347439  0.323534  0.087706  0.427077  0.313656  0.371549
# 1997  0.335606  0.318426  0.257948  0.225381  0.417769  0.123067  0.333455
# 1998  0.253910  0.171202  0.302622  0.181066  0.326383  0.167960  0.417409
# 1999  0.271575  0.149037  0.232753  0.197720  0.236424  0.187395  0.467213
#
# ...

# %%
# 参看特征是否存在缺失值
# print(df.isnull().any())
print(df.isnull().sum())
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 71    0
# 72    0
# 73    0
# 74    0
# 75    0
# Length: 76, dtype: int64

# %%
# 查看数据基本信息
print(df.describe()[0]['mean'])
(df.describe())
# Out:
# 0.18554426927000003
#                 0            1            2            3            4   \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.185544     0.377311     0.269378     0.265686     0.300367
# std       0.091898     0.176231     0.137980     0.110694     0.156256
# min       0.004928     0.009000     0.005624     0.010114     0.002090
# 25%       0.112066     0.223410     0.142086     0.195214     0.180421
# 50%       0.176093     0.401208     0.288355     0.255635     0.282515
# 75%       0.270290     0.523692     0.378611     0.325003     0.413297
# max       0.395772     0.771281     0.665372     0.748012     0.796487
#
#                 5            6            7            8            9   ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.158314     0.364771     0.247213     0.288657     0.151716  ...
# std       0.089022     0.144367     0.123856     0.115912     0.087224  ...
# ...

# %%
df[0].value_counts()
# Out:
# 0.271575    2
# 0.378177    2
# 0.311567    2
# 0.134289    2
# 0.295982    2
#            ..
# 0.270521    1
# 0.239252    1
# 0.281909    1
# 0.211095    1
# 0.319886    1
# Name: 0, Length: 1994, dtype: int64

# %% [markdown]
# ### 可视化

# %%
df[0].hist();
# plt.xlabel('0')
# ply.ylabel('frequency')

# %%
df_norm = (df - df.mean()) / (df.std())
print(df_norm)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.302125 -1.021382 -1.199823  0.042237  2.020474 -1.375596  0.414231
# 1    -1.484279 -1.142479 -1.187582 -0.348634  1.912971 -1.315372  0.459295
# 2    -1.647180 -0.849237 -1.164016 -1.246584  1.997540 -1.143086  0.733331
# 3    -1.340705 -0.904106 -1.370733  0.215960  1.574017 -1.264127  0.420969
# 4    -1.344696 -1.015443 -1.146093 -0.110449  1.971694 -1.512923  0.349635
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.148756 -0.883988  1.138512 -1.702581 -0.230091  0.696014  0.608194
# 1996 -0.364739 -0.169502  0.392491 -1.607858  0.810914  1.744991  0.046952
# 1997  1.632918 -0.334134 -0.082834 -0.364113  0.751347 -0.395936 -0.216917
# 1998  0.743927 -1.169536  0.240935 -0.764453  0.166496  0.108354  0.364614
# 1999  0.936154 -1.295312 -0.265437 -0.613997 -0.409220  0.326678  0.709598
#
# ...

# %%
df_norm[0].hist();

# %%
print(data.mean())
print(data.std())
# Out:
# 0     0.185544
# 1     0.377311
# 2     0.269378
# 3     0.265686
# 4     0.300367
#         ...
# 71    0.166702
# 72    0.230956
# 73    0.267786
# 74    0.143982
# 75    0.217792
# Length: 76, dtype: float64
# 0     0.091898
# 1     0.176231
# 2     0.137980
# 3     0.110694
# 4     0.156256
#         ...
# 71    0.091240
# 72    0.123441
# 73    0.131009
# 74    0.085663
# 75    0.122908
# Length: 76, dtype: float64

# %%
npdata = np.array(df_norm)
npdata
# Out:
# array([[-1.30212502, -1.02138227, -1.19982311, ...,  0.96619279,
#         -1.09745822,  1.0339323 ],
#        [-1.48427903, -1.14247929, -1.18758216, ...,  1.3548021 ,
#         -0.70046814,  1.10895538],
#        [-1.64717971, -0.84923749, -1.16401562, ...,  1.35290918,
#         -0.84924144,  0.35532666],
#        ...,
#        [ 1.63291759, -0.33413351, -0.08283385, ..., -0.96336405,
#         -1.22814245, -0.83965833],
#        [ 0.74392727, -1.16953627,  0.24093517, ..., -0.28596424,
#         -0.47065713, -0.71426539],
#        [ 0.93615398, -1.29531234, -0.26543729, ...,  0.0609415 ,
#         -1.43478484, -1.07845511]])

# %%
np.save("npdata.npy", npdata)

# %%
with open("npdata.npy", 'r') as f:
    for i in range(2000):
        data = f.readline()
        print(data)
        data_list = data.split()
        data = np.array(data_list).astype(np.float32)

        if (i % 200) < train_size_per_class:
            train_data.append(data)
        else:
            test_data.append(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-689b636bb0a4> in <module>
#       1 with open("npdata.npy", 'r') as f:
#       2     for i in range(2000):
# ----> 3         data = f.readline()
#       4         print(data)
#       5         data_list = data.split()
#
# ~/anaconda3/envs/FL/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x93 in position 0: invalid start byte

# %%
train_data = list()
test_data = list()
train_size_per_class = DATASIZE * TRAIN_PRECENT / 10

with open(dataset_file, 'r') as f:
    for i in range(DATASIZE):
        data = f.readline()
        data_list = data.split()
        data = np.array(data_list).astype(np.float32)

        if (i % 200) < train_size_per_class:
            train_data.append(data)
        else:
            test_data.append(data)
